# %%
#setup 1
import os
if os.path.exists("FruitFlyPheno"):
  # !cd FruitFlyPheno && git pull
else:
  # !git clone https://github.com/ThomWorm/FruitFlyPheno -b colab
# %pip install -q geoviews
# %pip install -q netCDF4
# %pip install -q xarray['io']
# Out:
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 28 (delta 20), reused 14 (delta 10), pack-reused 0 (from 0)
# Unpacking objects: 100% (28/28), 52.22 KiB | 1.93 MiB/s, done.
# From https://github.com/ThomWorm/FruitFlyPheno
#    984f5b5..0aebc37  main       -> origin/main
#  * [new branch]      colab      -> origin/colab
# Updating 984f5b5..0aebc37
# Fast-forward
#  fflies/colab_test.ipynb | 1386 ++++++++++++++++++++++++++++++++++++++---------
#  fflies/core/outputs.py  |   15 +-
#  2 files changed, 1137 insertions(+), 264 deletions(-)

# %%
#setup 2
import os
os.chdir("FruitFlyPheno/fflies")
from main import main as fflies

# %%
# modify the user input file to try different scenarios of species, dates
# and locations
# availible species are off, medfly, mexfly, z_tau, queensland
#the json is located in the config folder - navigate with the folder icon on the
#left, then edit and save

fflies(input_json="../config/sample_user_input_single.json", print_json=True)
# Out:
# Fetching weather data for: off from 2005-01-01 to now
# Weather data loaded
# Incomplete development detected, running prediction.
# Key                                           Value
# --------------------------------------------  ----------
# detection_date                                2025-01-27
# species                                       off
# latitude                                      37.523
# longitude                                     -121.961
# generations.F1.likely_completion_date         2025-05-23
# generations.F2.likely_completion_date         2025-07-22
# generations.F3.likely_completion_date         2025-09-13
# generations.F3.latest_likely_completion_date  2025-09-24

# %%
# we can also run multiple scenarios at once - this can easily be moved to a CSV input and paralellized
fflies(input_json="../config/sample_user_input_multi.json", print_json=True)

# %%
#for a sample of the deluxe output, use the plot function. Control the display with the dropdowns for Year/layer,
# Generation and Transparency
#please excuse the ugly yellow text - trying to get it to show up on the dark background
fflies(
    input_json="../config/sample_user_input_single.json", print_json=False, plot=True
)
# Out:
# Fetching weather data for: off from 2005-01-01 to now
# Weather data loaded
# Incomplete development detected, running prediction.
# WARNING:param.panel_extension: bokeh extension not recognized and will be skipped.
# WARNING:param.panel_extension:bokeh extension not recognized and will be skipped.
# /content/FruitFlyPheno/fflies/main.py:164: UserWarning: Using Panel interactively in Colab notebooks requires the jupyter_bokeh package to be installed. Install it with:
#
#     !pip install jupyter_bokeh
#
# and try again.
#   pn.extension("bokeh")
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
# ...
