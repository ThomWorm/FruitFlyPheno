# %%
from degree_day_equations import single_sine_horizontal_cutoff

# %%
single_sine_horizontal_cutoff(13, 15, 12, 100)
# Out:
# 2.0

# %%
single_sine_horizontal_cutoff(14, 14.00000000001, 12, 99999)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 single_sine_horizontal_cutoff(14, 14.00000000001, 12, 99999)
#
# NameError: name 'single_sine_horizontal_cutoff' is not defined

# %%
single_sine_horizontal_cutoff(1, 15, 12, 22)
# Out:
# 2.0
